# %%
import pandas as pd
import numpy as np

# %%
# read csv and turn it into a dataframe
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
# lenght of df
display(len(df))

# shape of df
df.shape
# Out:
# 126314
# (126314, 23)

# %%
# display top 5 data
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# display bottom 5 data
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.41  1704.39
# 126310         102            1     GSW   Warriors  104  1809.98  1813.63
# 126311         101            1     CLE  Cavaliers   91  1704.39  1700.74
# 126312         102            1     CLE  Cavaliers   97  1700.74  1692.09
# 126313         103            1     GSW   Warriors  105  1813.63  1822.29
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
# option to display max columns
pd.set_option("display.max_columns", None)

# %%
# option to display 2 decimal number
pd.set_option("display.precision", 2)
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts    elo_i    elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.00  1293.28      40.29    NYK
# 1            0     NYK   Knicks   68  1300.00  1306.72      41.71    TRH
# 2            0     CHS    Stags   63  1300.00  1309.65      42.01    NYK
# 3            0     NYK   Knicks   47  1306.72  1297.07      40.69    CHS
# 4            0     DTF  Falcons   33  1300.00  1279.62      38.86    WSC
#
#    opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  \
# ...

# %%
# display information of df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# simple statistical description
df.describe()
# df.describe(include=['0'])
# Out:
#        gameorder   _iscopy    year_id  seasongame  is_playoffs        pts  \
# count  126314.00  126314.0  126314.00   126314.00    126314.00  126314.00
# mean    31579.00       0.5    1988.20       43.53         0.06     102.73
# std     18231.93       0.5      17.58       25.38         0.24      14.81
# min         1.00       0.0    1947.00        1.00         0.00       0.00
# 25%     15790.00       0.0    1975.00       22.00         0.00      93.00
# 50%     31579.00       0.5    1990.00       43.00         0.00     103.00
# 75%     47368.00       1.0    2003.00       65.00         0.00     112.00
# max     63157.00       1.0    2015.00      108.00         1.00     186.00
#
#            elo_i      elo_n  win_equiv    opp_pts  opp_elo_i  opp_elo_n  \
# count  126314.00  126314.00  126314.00  126314.00  126314.00  126314.00
# mean     1495.24    1495.24      41.71     102.73    1495.24    1495.24
# std       112.14     112.46      10.63      14.81     112.14     112.46
# ...

# %%
# count values
df["team_id"].value_counts()
# Out:
# team_id
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: count, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# fran_id
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
# count values with cindition, make it into percentage
df.loc[df['fran_id'] == 'Lakers', "team_id"].value_counts(normalize=True)*100
# Out:
# team_id
# LAL    84.3
# MNL    15.7
# Name: proportion, dtype: float64

# %%
# minimum value
df.loc[df['team_id'] == 'MNL', "date_game"].min()
# Out:
# '1/1/1949'

# %%
# maximum value
df.loc[df['team_id'] == 'MNL', "date_game"].max()
# Out:
# '4/9/1959'

# %%
# get min and max with aggregation
df.loc[df['team_id'] == 'MNL', "date_game"].agg(('min','max'))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
# show every column in df
df.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#       dtype='object')

# %%
# sum every points with condition
df[df.team_id == 'BOS'].pts.sum()
# Out:
# 626484

# %%
# make a series
revenues = pd.Series([555,7000,9999])
revenues
# Out:
# 0     555
# 1    7000
# 2    9999
# dtype: int64

# %%
# series values
revenues.values
# Out:
# array([ 555, 7000, 9999], dtype=int64)

# %%
# series index
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
# making series with label index
city_revenues = pd.Series([555,7000,9999], index=['Jakarta', 'Bandung','Pekanbaru'])
city_revenues
# Out:
# Jakarta       555
# Bandung      7000
# Pekanbaru    9999
# dtype: int64

# %%
city_revenues.index
# Out:
# Index(['Jakarta', 'Bandung', 'Pekanbaru'], dtype='object')

# %%
# making series with dictionnary
city_employee_counts = pd.Series({'Jakarta':10, 'Bandung':56})
city_employee_counts
# Out:
# Jakarta    10
# Bandung    56
# dtype: int64

# %%
city_employee_counts.keys()
# Out:
# Index(['Jakarta', 'Bandung'], dtype='object')

# %%
'Jakarta' in city_employee_counts
# Out:
# True

# %%
# making a dataframe
city_data = pd.DataFrame({
    'revenue':city_revenues,
    'employee_count':city_employee_counts
})

city_data
# Out:
#            revenue  employee_count
# Bandung       7000            56.0
# Jakarta        555            10.0
# Pekanbaru     9999             NaN

# %%
city_data.index
# Out:
# Index(['Bandung', 'Jakarta', 'Pekanbaru'], dtype='object')

# %%
city_data.values
# Out:
# array([[7000.,   56.],
#        [ 555.,   10.],
#        [9999.,   nan]])

# %%
city_data.axes
# Out:
# [Index(['Bandung', 'Jakarta', 'Pekanbaru'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[1]
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['revenue', 'employee_count'], dtype='object')

# %%
'revenue' in city_data
# Out:
# True

# %%
'Bandung' in city_data
# Out:
# False

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
'pts' in df
# Out:
# True

# %%
'points' in df
# Out:
# False

# %%
city_revenues
# Out:
# Jakarta       555
# Bandung      7000
# Pekanbaru    9999
# dtype: int64

# %%
city_revenues['Jakarta']
# Out:
# 555

# %%
city_revenues.iloc[0]
# Out:
# 555

# %%
city_revenues[:2]
# Out:
# Jakarta     555
# Bandung    7000
# dtype: int64

# %%
city_revenues['Bandung':]
# Out:
# Bandung      7000
# Pekanbaru    9999
# dtype: int64

# %%
colors = pd.Series(
    ['red', 'purple','blue','green','yellow'],
    index = [1,2,3,5,8]
)
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors[8]
# Out:
# 'yellow'

# %%
# loc menggunakan label index
colors.loc[2]
# Out:
# 'purple'

# %%
# iloc menggunakan positional index
display(colors.iloc[2])     
colors.iloc[-2]
# Out:
# 'blue'
# 'green'

# %%
colors.iloc[1:3]
# Out:
# 2    purple
# 3      blue
# dtype: object

# %%
colors.iloc[3:8]
# Out:
# 5     green
# 8    yellow
# dtype: object

# %%
city_data.revenue
# Out:
# Bandung      7000
# Jakarta       555
# Pekanbaru    9999
# Name: revenue, dtype: int64

# %%
# aking a dataframe with dictionary
toys = pd.DataFrame([{"name A": "ball", "shape": "sphere"}, {"name A": "Rubik's cube", "shape": "cube"}])
toys
# Out:
#          name A   shape
# 0          ball  sphere
# 1  Rubik's cube    cube

# %%
toys['name A']
# Out:
# 0            ball
# 1    Rubik's cube
# Name: name A, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %%
city_data
# Out:
#            revenue  employee_count
# Bandung       7000            56.0
# Jakarta        555            10.0
# Pekanbaru     9999             NaN

# %%
city_data.loc['Bandung']
# Out:
# revenue           7000.0
# employee_count      56.0
# Name: Bandung, dtype: float64

# %%
city_data.iloc[0]
# Out:
# revenue           7000.0
# employee_count      56.0
# Name: Bandung, dtype: float64

# %%
city_data.loc['Jakarta':'Pekanbaru']
# Out:
#            revenue  employee_count
# Jakarta        555            10.0
# Pekanbaru     9999             NaN

# %%
city_data.iloc[1:3]
# Out:
#            revenue  employee_count
# Jakarta        555            10.0
# Pekanbaru     9999             NaN

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
df.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i                 1700.74
# elo_n                 1692.09
# win_equiv               59.29
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i             1813.63
# opp_elo_n             1822.29
# game_location               H
# game_result                 L
# forecast                 0.48
# notes                     NaN
# Name: 126312, dtype: object

# %%
df.iloc[-2,0:5]
# Out:
# gameorder           63157
# game_id      201506170CLE
# lg_id                 NBA
# _iscopy                 0
# year_id              2015
# Name: 126312, dtype: object

# %%
df.loc[126310:126312,'game_id':'year_id']
# Out:
#              game_id lg_id  _iscopy  year_id
# 126310  201506140GSW   NBA        0     2015
# 126311  201506140GSW   NBA        1     2015
# 126312  201506170CLE   NBA        0     2015

# %%
df.loc[126312:126313,['game_id','game_result','team_id','opp_id']]
# Out:
#              game_id game_result team_id opp_id
# 126312  201506170CLE           L     CLE    GSW
# 126313  201506170CLE           W     GSW    CLE

# %%
current_decade = df[df['year_id'] > 2010]

# %%
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 113656           1            0     MIA       Heat   80  1547.36  1543.16
# ...

# %%
# get non null values
df[df.notes.notnull()]
df[df.notes.notna()]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# ...

# %%
df.fran_id.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: fran_id
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  object
# dtypes: object(1)
# memory usage: 987.0+ KB

# %%
# using string function
df[df.fran_id.str.endswith('ers')]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 7               4  194611020PRO   NBA        0     1947  11/2/1946
# 9               5  194611020STB   NBA        0     1947  11/2/1946
# 16              9  194611050DTF   NBA        1     1947  11/5/1946
# 20             11  194611070PRO   NBA        0     1947  11/7/1946
# 22             12  194611070STB   NBA        0     1947  11/7/1946
# ...           ...           ...   ...      ...      ...        ...
# 126304      63153  201506070GSW   NBA        1     2015   6/7/2015
# 126307      63154  201506090CLE   NBA        0     2015   6/9/2015
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts    elo_i    elo_n  \
# 7                1            0     PRO  Steamrollers   59  1300.00  1305.15
# ...

# %%
notes_nonull = df.notes.notnull()

# %%
tahun = df.year_id >= 2001

# %%
# slicing df with condition
df[(df.fran_id.str.endswith('ers')) & (notes_nonull) & (tahun) & (df['_iscopy'] == 0)]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 95379       47690  200310300SEA   NBA        0     2004  10/30/2003
# 95384       47693  200310310LAC   NBA        0     2004  10/31/2003
# 110348      55175  200903130PHI   NBA        0     2009   3/13/2009
#
#         seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 95379            1            0     LAC  Clippers  100  1428.09  1421.46
# 95384            2            0     LAC  Clippers  105  1421.46  1411.31
# 110348          63            0     PHI    Sixers  104  1507.57  1510.89
#
#         win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 95379       32.56    SEA  Thunder      109    1523.13    1529.76
# 95384       31.54    SEA  Thunder      124    1529.76    1539.91
# 110348      41.89    CHI    Bulls      101    1482.24    1478.92
#
#        game_location game_result  forecast  \
# 95379              N           L      0.37
# ...

# %%
df[(df['team_id'].str.startswith('LA')) & (tahun) & (df._iscopy == 0) & (notes_nonull)]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 95379      47690  200310300SEA   NBA        0     2004  10/30/2003
# 95384      47693  200310310LAC   NBA        0     2004  10/31/2003
#
#        seasongame  is_playoffs team_id   fran_id  pts    elo_i    elo_n  \
# 95379           1            0     LAC  Clippers  100  1428.09  1421.46
# 95384           2            0     LAC  Clippers  105  1421.46  1411.31
#
#        win_equiv opp_id opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 95379      32.56    SEA  Thunder      109    1523.13    1529.76             N
# 95384      31.54    SEA  Thunder      124    1529.76    1539.91             N
#
#       game_result  forecast              notes
# 95379           L      0.37  at Saitama, Japan
# 95384           L      0.35  at Saitama, Japan

# %%
poin = df['pts']
poin.sum()
# Out:
# 12976235

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# grouping df by column 
df.groupby('fran_id', sort = False)['pts'].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df[(df.fran_id.str.endswith('ers')) & (notes_nonull) & (tahun) & (df['_iscopy'] == 0)].groupby(['year_id','game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2004     L              2
# 2009     W              1
# Name: game_id, dtype: int64

# %%
df.groupby(['year_id','game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 1947     L               350
#          W               350
# 1948     L               215
#          W               215
# 1949     L               380
#                         ...
# 2013     W              1314
# 2014     L              1319
#          W              1319
# 2015     L              1311
#          W              1311
# Name: game_id, Length: 138, dtype: int64

# %%
df[(df.year_id == 2015) & (df.team_id == 'GSW')].groupby(['is_playoffs','game_result'])['game_id'].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %%
# copying a dataframe
nba = df.copy()
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# make a new column
nba['difference'] = nba.pts - nba.opp_pts
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba['difference'].max()
# Out:
# 68

# %%
# renaming columns
renamed_nba = nba.rename(columns= {"game_result":"result", "game_location":"location"})
renamed_nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
# inplace for updating a dataframe
nba.rename(columns= {"game_result":"result", "game_location":"location"}, inplace = True)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts    elo_i    elo_n  \
# 0                1            0     TRH    Huskies   66  1300.00  1293.28
# ...

# %%
nba.columns
# Out:
# Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#        'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#        'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#        'opp_elo_n', 'location', 'result', 'forecast', 'notes', 'difference'],
#       dtype='object')

# %%
elo_columns = ['elo_i','elo_n','opp_elo_i','opp_elo_n',]

# %%
# drop is for deleting column / row
nba.drop(columns = elo_columns, inplace = True)

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
nba['date_game'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: date_game
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  object
# dtypes: object(1)
# memory usage: 987.0+ KB

# %%
# changing data to date time
nba['date_game']=pd.to_datetime(nba['date_game'])

# %%
nba['date_game'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 126314 entries, 0 to 126313
# Series name: date_game
# Non-Null Count   Dtype
# --------------   -----
# 126314 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 987.0 KB

# %%
# total unique values
nba.location.unique()
# Out:
# array(['H', 'A', 'N'], dtype=object)

# %%
nba.location.value_counts()
# Out:
# location
# H    63138
# A    63138
# N       38
# Name: count, dtype: int64

# %%
# data type
nba.location.dtype
# Out:
# dtype('O')

# %%
# changing type into categorical
nba.location = pd.Categorical(nba.location)

# %%
nba.location.dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False, categories_dtype=object)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  category
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
# drop null values
non_null_notes = nba.dropna()
non_null_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 930           466  194801300BLB   NBA        1     1948 1948-01-30
# 931           466  194801300BLB   NBA        0     1948 1948-01-30
# 1084          543  194803230CHS   NBA        1     1948 1948-03-23
# 1085          543  194803230CHS   NBA        0     1948 1948-03-23
# 1088          545  194803250CHS   NBA        1     1948 1948-03-25
# ...           ...           ...   ...      ...      ...        ...
# 122207      61104  201401160ATL   NBA        0     2014 2014-01-16
# 123916      61959  201411120MIN   NBA        1     2015 2014-11-12
# 123917      61959  201411120MIN   NBA        0     2015 2014-11-12
# 124862      62432  201501150MIL   NBA        0     2015 2015-01-15
# 124863      62432  201501150MIL   NBA        1     2015 2015-01-15
#
#         seasongame  is_playoffs team_id       fran_id  pts  win_equiv opp_id  \
# 930             28            0     WSC      Capitols   71      47.07    BLB
# ...

# %%
data_without_missing_columns = nba.dropna(axis = 1)
data_without_missing_columns
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
# fill null values
data_with_default_notes = nba.copy()
data_with_default_notes['notes'].fillna(
    value = "no notes at all",
    inplace = True
)
data_with_default_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66      40.29    NYK
# ...

# %%
data_with_default_notes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   gameorder    126314 non-null  int64
#  1   game_id      126314 non-null  object
#  2   lg_id        126314 non-null  object
#  3   _iscopy      126314 non-null  int64
#  4   year_id      126314 non-null  int64
#  5   date_game    126314 non-null  datetime64[ns]
#  6   seasongame   126314 non-null  int64
#  7   is_playoffs  126314 non-null  int64
#  8   team_id      126314 non-null  object
#  9   fran_id      126314 non-null  object
#  10  pts          126314 non-null  int64
#  11  win_equiv    126314 non-null  float64
#  12  opp_id       126314 non-null  object
#  13  opp_fran     126314 non-null  object
#  14  opp_pts      126314 non-null  int64
#  15  location     126314 non-null  category
#  16  result       126314 non-null  object
#  17  forecast     126314 non-null  float64
# ...

# %%
nba.describe()
# Out:
#        gameorder   _iscopy    year_id                      date_game  \
# count  126314.00  126314.0  126314.00                         126314
# mean    31579.00       0.5    1988.20  1988-04-09 00:53:18.429311104
# min         1.00       0.0    1947.00            1946-11-01 00:00:00
# 25%     15790.00       0.0    1975.00            1974-11-08 00:00:00
# 50%     31579.00       0.5    1990.00            1990-02-06 00:00:00
# 75%     47368.00       1.0    2003.00            2003-03-19 00:00:00
# max     63157.00       1.0    2015.00            2015-06-16 00:00:00
# std     18231.93       0.5      17.58                            NaN
#
#        seasongame  is_playoffs        pts  win_equiv    opp_pts   forecast  \
# count   126314.00    126314.00  126314.00  126314.00  126314.00  126314.00
# mean        43.53         0.06     102.73      41.71     102.73       0.50
# min          1.00         0.00       0.00      10.15       0.00       0.02
# ...

# %%
nba[nba.pts == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0      40.41    VIR  Squires        2
#
#       location result  forecast                           notes  difference
# 26684        A      L      0.33  at Richmond VA; forfeit to VIR          -2

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["result"] != 'L')].empty
# Out:
# False

# %%
further_city_data = pd.DataFrame(
{"revenue": [7000, 3400], "employee_count": [2, 2]}, index=["New York", "Barcelona"])

# %%
city_data
# Out:
#            revenue  employee_count
# Bandung       7000            56.0
# Jakarta        555            10.0
# Pekanbaru     9999             NaN

# %%
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
# appending 2 or more dataframes
all_city_data = pd.concat([further_city_data, city_data])
all_city_data
# Out:
#            revenue  employee_count
# New York      7000             2.0
# Barcelona     3400             2.0
# Bandung       7000            56.0
# Jakarta        555            10.0
# Pekanbaru     9999             NaN

# %%
city_countries = pd.DataFrame({ "country": ["Holland", "Japan", "Holland", "Canada", "Spain"], "capital": [1, 1, 0, 0, 0]},
index=["Bandung", "Jakarta", "Pekanbaru", "Toronto", "Barcelona"])

# %%
city_countries
# Out:
#            country  capital
# Bandung    Holland        1
# Jakarta      Japan        1
# Pekanbaru  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
cities = pd.concat([all_city_data, city_countries], axis = 1)
cities
# Out:
#            revenue  employee_count  country  capital
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Bandung     7000.0            56.0  Holland      1.0
# Jakarta      555.0            10.0    Japan      1.0
# Pekanbaru   9999.0             NaN  Holland      0.0
# Toronto        NaN             NaN   Canada      0.0

# %%
pd.concat([all_city_data, city_countries], axis = 1, join = 'inner')
# Out:
#            revenue  employee_count  country  capital
# Barcelona     3400             2.0    Spain        0
# Bandung       7000            56.0  Holland        1
# Jakarta        555            10.0    Japan        1
# Pekanbaru     9999             NaN  Holland        0

# %%
countries = pd.DataFrame({ "population_millions": [17, 127, 37],
"continent":["Europe", "Asia", "North America"]
}, index=["Bandung", "Jakarta", "Canada"])

# %%
countries
# Out:
#          population_millions      continent
# Bandung                   17         Europe
# Jakarta                  127           Asia
# Canada                    37  North America

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Bandung     7000.0            56.0  Holland      1.0
# Jakarta      555.0            10.0    Japan      1.0
# Pekanbaru   9999.0             NaN  Holland      0.0
# Toronto        NaN             NaN   Canada      0.0

# %%
# joining 2 or more dataframes
pd.merge(cities, countries, left_on='country', right_index = True, how='outer')
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Bandung     7000.0            56.0  Holland      1.0                  NaN
# Pekanbaru   9999.0             NaN  Holland      0.0                  NaN
# Jakarta      555.0            10.0    Japan      1.0                  NaN
# Toronto        NaN             NaN   Canada      0.0                 37.0
# NaN            NaN             NaN  Bandung      NaN                 17.0
# NaN            NaN             NaN  Jakarta      NaN                127.0
#
#                continent
# New York             NaN
# Barcelona            NaN
# Bandung              NaN
# Pekanbaru            NaN
# Jakarta              NaN
# Toronto    North America
# NaN               Europe
# NaN                 Asia

# %%
# %matplotlib inline

# %%
# making graph
nba[nba.fran_id == 'Knicks'].groupby('year_id')['pts'].sum().plot()
# Out:
# <Axes: xlabel='year_id'>

# %%
nba.fran_id.value_counts().head(10).plot(kind = 'bar')
# Out:
# <Axes: xlabel='fran_id'>
